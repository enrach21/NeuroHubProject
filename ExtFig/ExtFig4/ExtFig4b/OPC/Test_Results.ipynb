# %%
library(PRROC)

# %% [markdown]
# # MG

# %%
pos <- read.table('MG_Pos_chr2_predict_output.txt')
dim(pos)
head(pos)
# Out:
# [1] 5729    2
#   V1                              V2
# 1 chr2_64767406_64768405_pos_25    0.895112
# 2 chr2_9778132_9779131_pos_26      0.644488
# 3 chr2_231168422_231169421_pos_45 -0.026056
# 4 chr2_44167600_44168599_pos_50    1.091320
# 5 chr2_67477283_67478282_pos_58   -0.210116
# 6 chr2_97699852_97700851_pos_66   -0.270691

# %%
neg <- read.table('MG_Neg_chr2_predict_output.txt')
dim(neg)
head(neg)
# Out:
# [1] 5451    2
#   V1                               V2
# 1 chr2_96598332_96599331_neg_17    -2.168680
# 2 chr2_14101273_14102272_neg_55    -1.655390
# 3 chr2_71021955_71022954_neg_105   -1.854770
# 4 chr2_8625396_8626395_neg_112      0.336172
# 5 chr2_238083307_238084306_neg_120 -1.461380
# 6 chr2_239670970_239671969_neg_124  0.730159

# %%
pr <- pr.curve(pos$V2, neg$V2, curve=T)
plot(pr)
roc <- roc.curve(pos$V2, neg$V2, curve=T)
plot(roc)
# Out:
# Plot with title “PR curve
# AUC = 0.8548152”
# Plot with title “ROC curve
# AUC = 0.8455835”

# %% [markdown]
# # OPC

# %%
pos <- read.table('OPC_Pos_chr2_predict_output.txt')
dim(pos)
head(pos)
# Out:
# [1] 6141    2
#   V1                              V2
# 1 chr2_181022337_181023336_pos_4  0.112004
# 2 chr2_64608950_64609949_pos_21   2.762670
# 3 chr2_64214183_64215182_pos_22   0.327013
# 4 chr2_219748772_219749771_pos_27 0.162287
# 5 chr2_9139396_9140395_pos_32     1.100080
# 6 chr2_67877069_67878068_pos_34   0.470459

# %%
neg <- read.table('OPC_Neg_chr2_predict_output.txt')
dim(neg)
head(neg)
# Out:
# [1] 5772    2
#   V1                              V2
# 1 chr2_66024908_66025907_neg_6    -0.512285
# 2 chr2_40286875_40287874_neg_8     0.580580
# 3 chr2_144471142_144472141_neg_37 -0.979651
# 4 chr2_112010639_112011638_neg_44 -0.331632
# 5 chr2_26655422_26656421_neg_53    0.262459
# 6 chr2_240697906_240698905_neg_65 -0.774050

# %%
pr <- pr.curve(pos$V2, neg$V2, curve=T)
plot(pr)
roc <- roc.curve(pos$V2, neg$V2, curve=T)
plot(roc)
# Out:
# Plot with title “PR curve
# AUC = 0.9570902”
# Plot with title “ROC curve
# AUC = 0.9565546”

# %%
pdf('OPC_AUCROC.pdf', height = 4, width = 3.5)
plot(roc, legend=FALSE, color='#1B7837', cex.lab=1.5, cex.axis=1, cex.main=1.5, cex.sub=1.5)
dev.off()
# Out:
# png
#   2

# %% [markdown]
# # oRG

# %%
pos <- read.table('oRG_Pos_chr2_predict_output.txt')
dim(pos)
head(pos)
# Out:
# [1] 6590    2
#   V1                              V2
# 1 chr2_11132300_11133299_pos_4    2.448810
# 2 chr2_197079916_197080915_pos_5  0.532464
# 3 chr2_162036669_162037668_pos_19 1.331320
# 4 chr2_231056380_231057379_pos_22 2.109590
# 5 chr2_206800236_206801235_pos_67 1.161550
# 6 chr2_142716601_142717600_pos_75 0.656243

# %%
neg <- read.table('oRG_Neg_chr2_predict_output.txt')
dim(neg)
head(neg)
# Out:
# [1] 5906    2
#   V1                              V2
# 1 chr2_110951615_110952614_neg_14 -1.0095000
# 2 chr2_233227265_233228264_neg_28 -0.6747000
# 3 chr2_241011028_241012027_neg_37 -0.8443860
# 4 chr2_119637093_119638092_neg_50  0.7468300
# 5 chr2_38540663_38541662_neg_80   -0.5641990
# 6 chr2_232390742_232391741_neg_83  0.0375183

# %%
pr <- pr.curve(pos$V2, neg$V2, curve=T)
plot(pr)
roc <- roc.curve(pos$V2, neg$V2, curve=T)
plot(roc)
# Out:
# Plot with title “PR curve
# AUC = 0.9379482”
# Plot with title “ROC curve
# AUC = 0.9309545”

# %% [markdown]
# # vRG

# %%
pos <- read.table('vRG_Pos_chr2_predict_output.txt')
dim(pos)
head(pos)
# Out:
# [1] 6675    2
#   V1                              V2
# 1 chr2_9770061_9771060_pos_2       1.393070
# 2 chr2_210170269_210171268_pos_10  1.573960
# 3 chr2_20629483_20630482_pos_14   -0.176510
# 4 chr2_134276187_134277186_pos_20 -0.296714
# 5 chr2_216402415_216403414_pos_21  0.825864
# 6 chr2_124763309_124764308_pos_31  1.618740

# %%
neg <- read.table('vRG_Neg_chr2_predict_output.txt')
dim(neg)
head(neg)
# Out:
# [1] 5867    2
#   V1                              V2
# 1 chr2_118724131_118725130_neg_1  -1.700110
# 2 chr2_120382149_120383148_neg_39 -0.445798
# 3 chr2_72765005_72766004_neg_61   -2.986320
# 4 chr2_219074225_219075224_neg_65 -0.905840
# 5 chr2_57831769_57832768_neg_69   -1.259160
# 6 chr2_124194944_124195943_neg_89  0.514489

# %%
pr <- pr.curve(pos$V2, neg$V2, curve=T)
plot(pr)
roc <- roc.curve(pos$V2, neg$V2, curve=T)
plot(roc)
# Out:
# Plot with title “PR curve
# AUC = 0.9320343”
# Plot with title “ROC curve
# AUC = 0.9226409”
