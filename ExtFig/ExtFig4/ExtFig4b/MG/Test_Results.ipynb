# %%
library(PRROC)

# %% [markdown]
# # MG

# %%
pos <- read.table('MG_Pos_chr2_predict_output.txt')
dim(pos)
head(pos)
# Out:
# [1] 5729    2
#   V1                              V2
# 1 chr2_64767406_64768405_pos_25   1.489270
# 2 chr2_9778132_9779131_pos_26     0.686923
# 3 chr2_231168422_231169421_pos_45 1.609740
# 4 chr2_44167600_44168599_pos_50   0.466819
# 5 chr2_67477283_67478282_pos_58   1.207370
# 6 chr2_97699852_97700851_pos_66   0.836205

# %%
neg <- read.table('MG_Neg_chr2_predict_output.txt')
dim(neg)
head(neg)
# Out:
# [1] 5451    2
#   V1                               V2
# 1 chr2_96598332_96599331_neg_17    -1.086880
# 2 chr2_14101273_14102272_neg_55    -1.267910
# 3 chr2_71021955_71022954_neg_105   -1.211370
# 4 chr2_8625396_8626395_neg_112     -1.076150
# 5 chr2_238083307_238084306_neg_120 -1.311070
# 6 chr2_239670970_239671969_neg_124 -0.865638

# %%
pr <- pr.curve(pos$V2, neg$V2, curve=T)
plot(pr)
roc <- roc.curve(pos$V2, neg$V2, curve=T)
plot(roc)
# Out:
# Plot with title “PR curve
# AUC = 0.9612294”
# Plot with title “ROC curve
# AUC = 0.9612143”

# %%
pdf('MG_AUCROC.pdf', height = 4, width = 3.5)
plot(roc, legend=FALSE, color='#762A83', cex.lab=1.5, cex.axis=1, cex.main=1.5, cex.sub=1.5)
dev.off()
# Out:
# png
#   2

# %% [markdown]
# # OPC

# %%
pos <- read.table('OPC_Pos_chr2_predict_output.txt')
dim(pos)
head(pos)
# Out:
# [1] 6141    2
#   V1                              V2
# 1 chr2_181022337_181023336_pos_4  -0.377240
# 2 chr2_64608950_64609949_pos_21    2.116530
# 3 chr2_64214183_64215182_pos_22    0.345605
# 4 chr2_219748772_219749771_pos_27 -1.661920
# 5 chr2_9139396_9140395_pos_32      0.141307
# 6 chr2_67877069_67878068_pos_34    0.818844

# %%
neg <- read.table('OPC_Neg_chr2_predict_output.txt')
dim(neg)
head(neg)
# Out:
# [1] 5772    2
#   V1                              V2
# 1 chr2_66024908_66025907_neg_6    -1.9178800
# 2 chr2_40286875_40287874_neg_8    -0.0373802
# 3 chr2_144471142_144472141_neg_37 -1.0859800
# 4 chr2_112010639_112011638_neg_44 -0.4642140
# 5 chr2_26655422_26656421_neg_53   -0.2616690
# 6 chr2_240697906_240698905_neg_65 -2.3058800

# %%
pr <- pr.curve(pos$V2, neg$V2, curve=T)
plot(pr)
roc <- roc.curve(pos$V2, neg$V2, curve=T)
plot(roc)
# Out:
# Plot with title “PR curve
# AUC = 0.8919681”
# Plot with title “ROC curve
# AUC = 0.881918”

# %% [markdown]
# # oRG

# %%
pos <- read.table('oRG_Pos_chr2_predict_output.txt')
dim(pos)
head(pos)
# Out:
# [1] 6590    2
#   V1                              V2
# 1 chr2_11132300_11133299_pos_4    1.938380
# 2 chr2_197079916_197080915_pos_5  0.203725
# 3 chr2_162036669_162037668_pos_19 0.178921
# 4 chr2_231056380_231057379_pos_22 0.951446
# 5 chr2_206800236_206801235_pos_67 0.893618
# 6 chr2_142716601_142717600_pos_75 0.980176

# %%
neg <- read.table('oRG_Neg_chr2_predict_output.txt')
dim(neg)
head(neg)
# Out:
# [1] 5906    2
#   V1                              V2
# 1 chr2_110951615_110952614_neg_14 -0.7616970
# 2 chr2_233227265_233228264_neg_28 -1.1223600
# 3 chr2_241011028_241012027_neg_37 -0.9375280
# 4 chr2_119637093_119638092_neg_50 -0.0673282
# 5 chr2_38540663_38541662_neg_80   -2.0049200
# 6 chr2_232390742_232391741_neg_83 -0.4687360

# %%
pr <- pr.curve(pos$V2, neg$V2, curve=T)
plot(pr)
roc <- roc.curve(pos$V2, neg$V2, curve=T)
plot(roc)
# Out:
# Plot with title “PR curve
# AUC = 0.8688976”
# Plot with title “ROC curve
# AUC = 0.8502893”

# %% [markdown]
# # vRG

# %%
pos <- read.table('vRG_Pos_chr2_predict_output.txt')
dim(pos)
head(pos)
# Out:
# [1] 6675    2
#   V1                              V2
# 1 chr2_9770061_9771060_pos_2       0.376892
# 2 chr2_210170269_210171268_pos_10  1.357540
# 3 chr2_20629483_20630482_pos_14   -0.326107
# 4 chr2_134276187_134277186_pos_20  0.288192
# 5 chr2_216402415_216403414_pos_21  0.886686
# 6 chr2_124763309_124764308_pos_31  0.938659

# %%
neg <- read.table('vRG_Neg_chr2_predict_output.txt')
dim(neg)
head(neg)
# Out:
# [1] 5867    2
#   V1                              V2
# 1 chr2_118724131_118725130_neg_1  -1.208340
# 2 chr2_120382149_120383148_neg_39 -0.101330
# 3 chr2_72765005_72766004_neg_61   -3.738670
# 4 chr2_219074225_219075224_neg_65 -1.624070
# 5 chr2_57831769_57832768_neg_69   -1.550120
# 6 chr2_124194944_124195943_neg_89  0.164763

# %%
pr <- pr.curve(pos$V2, neg$V2, curve=T)
plot(pr)
roc <- roc.curve(pos$V2, neg$V2, curve=T)
plot(roc)
# Out:
# Plot with title “PR curve
# AUC = 0.9430963”
# Plot with title “ROC curve
# AUC = 0.9349722”
